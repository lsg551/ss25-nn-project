# %% [markdown]
# # Listwise Cross-Encoder

# %%
import os
import sys

sys.path.append(os.path.abspath(".."))  # make src available as a package

# %%
from src.data import MSMARCO


train_dl, val_dl, test_dl = MSMARCO.as_dataloaders()

# %%
from typing import cast
from IPython.display import display
from src.data.msmarco import MSMARCOBatch
from src.models.CrossEncoderLongformer import CrossEncoderLongformer, tokenizer

sample = cast(MSMARCOBatch, next(iter(train_dl)))
query = sample["queries"][0]
candidates = sample["candidates"][0]


model = CrossEncoderLongformer()

encoding = model.tokenize(query, candidates)
display(tokenizer.convert_ids_to_tokens(encoding["input_ids"][0]))
logits, cand_mask = model.forward(encoding)

print(f"Query: {query}")
print(f"Candidates ({len(candidates)}): {candidates}")
print(logits, cand_mask)
# Out:
# ['<s>',
#  'who',
#  'Ġis',
#  'Ġthe',
#  'Ġleader',
#  'Ġof',
#  'Ġthe',
#  'Ġexecutive',
#  'Ġbranch',
#  'Ġof',
#  'Ġgovernment',
#  '.',
#  '</s>',
#  '[CAND]',
#  'Each',
#  'Ġbranch',
#  'Ġof',
#  'Ġgovernment',
#  'Ġcan',
#  'Ġchange',
#  'Ġacts',
#  'Ġof',
#  'Ġthe',
#  'Ġother',
#  'Ġbranches',
#  'Ġas',
#  'Ġfollows',
#  ':',
#  'Ġ1',
#  'Ġ',
#  'ĠThe',
#  'ĠPresident',
#  'Ġcan',
#  'Ġveto',
#  'Ġlaws',
#  'Ġpassed',
#  'Ġby',
#  'ĠCongress',
#  '.',
#  'Ġ2',
#  'Ġ',
#  'ĠCongress',
#  'Ġconfirms',
#  'Ġor',
#  'Ġrejects',
#  'Ġthe',
#  'ĠPresident',
#  "'s",
#  'Ġappointments',
#  'Ġand',
#  'Ġcan',
#  'Ġremove',
#  'Ġthe',
#  'ĠPresident',
#  'Ġfrom',
#  'Ġoffice',
#  'Ġin',
#  'Ġexceptional',
#  'Ġcircumstances',
#  '.',
#  '</s>',
#  '[CAND]',
#  'Br',
#  'anches',
#  'Ġof',
#  'ĠGovernment',
#  '.',
#  'ĠLearn',
#  'Ġabout',
#  'Ġthe',
#  'Ġexecutive',
#  ',',
#  'Ġlegislative',
#  ',',
#  'Ġand',
#  'Ġjudicial',
#  'Ġbranches',
#  'Ġof',
#  'Ġthe',
#  'ĠU',
#  '.',
# ...
