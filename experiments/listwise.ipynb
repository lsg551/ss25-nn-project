# %% [markdown]
# # Listwise Cross-Encoder

# %%
import os
import sys

sys.path.append(os.path.abspath(".."))  # make src available as a package

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# for Apple's Metal (MPS) backend / framework
if torch.backends.mps.is_available():
    device = torch.device("mps")

print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # 1. Training

# %%
from src.data import MSMARCO

train_dl, val_dl, test_dl = MSMARCO.as_dataloaders()

# %%
# custom PyTorch loss function for ListNet
def listNet(output, target): ...

# %% [markdown]
# WARNING:
#
# Candidates seems to be very unequally distributed in length.
# Some are very short, some are very long. This causes a lot of padding
# in the batch – and I haven't yet figured out how to deal with that (if at all).

# %%
from typing import cast
from IPython.display import display
from transformers import BatchEncoding
from src.data.msmarco import MSMARCOBatch
from src.models.CrossEncoderLongformer import CrossEncoderLongformer, print_encoded
import torch

sample = cast(MSMARCOBatch, next(iter(train_dl)))

model = CrossEncoderLongformer().to(device)

# convenience function for batch tokenization
def tokenize(batch: MSMARCOBatch):
    return CrossEncoderLongformer.batch_tokenize(
        batch["queries"],
        batch["candidates"],
    ).to(device)

input = tokenize(sample)
# print_encoded(input)
logits, cand_mask = model(input)

print(logits, cand_mask)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[6], line 21
#      19 input = tokenize(sample)
#      20 # print_encoded(input)
# ---> 21 logits, cand_mask = model(input)
#      23 print(logits, cand_mask)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ss25-nn-project/src/models/CrossEncoderLongformer.py:174, in CrossEncoderLongformer.forward(self, x)
#     151 """Forward pass of the Longformer cross-encoder.
#     152
#     153 Example:
#    (...)    166     _type_: _description_
#     167 """
#     168 # B = batch size
#     169 # L = sequence length (num tokens in input after truncation/padding)
#     170 # H = dimensionality of the hidden representations for each token
#     171 #     (e.g., 768 for Longformer)
#     172 # Example: if a batch with 4 samples and max length 512 is fed into the model
#     173 # with a hidden size of 768, this will be (4, 512, 768)
# --> 174 outputs = self.longformer(**x)
#     175 hidden = outputs.last_hidden_state  # (B, L, H)
#     176 # x["input_ids"] is (B, L)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/models/longformer/modeling_longformer.py:1600, in LongformerModel.forward(self, input_ids, attention_mask, global_attention_mask, head_mask, token_type_ids, position_ids, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1592 extended_attention_mask: torch.Tensor = self.get_extended_attention_mask(attention_mask, input_shape)[
#    1593     :, 0, 0, :
#    1594 ]
#    1596 embedding_output = self.embeddings(
#    1597     input_ids=input_ids, position_ids=position_ids, token_type_ids=token_type_ids, inputs_embeds=inputs_embeds
#    1598 )
# -> 1600 encoder_outputs = self.encoder(
#    1601     embedding_output,
#    1602     attention_mask=extended_attention_mask,
#    1603     head_mask=head_mask,
#    1604     padding_len=padding_len,
#    1605     output_attentions=output_attentions,
#    1606     output_hidden_states=output_hidden_states,
#    1607     return_dict=return_dict,
#    1608 )
#    1609 sequence_output = encoder_outputs[0]
#    1610 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/models/longformer/modeling_longformer.py:1259, in LongformerEncoder.forward(self, hidden_states, attention_mask, head_mask, padding_len, output_attentions, output_hidden_states, return_dict)
#    1256 if output_hidden_states:
#    1257     all_hidden_states = all_hidden_states + (hidden_states,)
# -> 1259 layer_outputs = layer_module(
#    1260     hidden_states,
#    1261     attention_mask=attention_mask,
#    1262     layer_head_mask=head_mask[idx] if head_mask is not None else None,
#    1263     is_index_masked=is_index_masked,
#    1264     is_index_global_attn=is_index_global_attn,
#    1265     is_global_attn=is_global_attn,
#    1266     output_attentions=output_attentions,
#    1267 )
#    1268 hidden_states = layer_outputs[0]
#    1270 if output_attentions:
#    1271     # bzs x seq_len x num_attn_heads x (num_global_attn + attention_window_len + 1) => bzs x num_attn_heads x seq_len x (num_global_attn + attention_window_len + 1)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/models/longformer/modeling_longformer.py:1199, in LongformerLayer.forward(self, hidden_states, attention_mask, layer_head_mask, is_index_masked, is_index_global_attn, is_global_attn, output_attentions)
#    1189 def forward(
#    1190     self,
#    1191     hidden_states,
#    (...)   1197     output_attentions=False,
#    1198 ):
# -> 1199     self_attn_outputs = self.attention(
#    1200         hidden_states,
#    1201         attention_mask=attention_mask,
#    1202         layer_head_mask=layer_head_mask,
#    1203         is_index_masked=is_index_masked,
#    1204         is_index_global_attn=is_index_global_attn,
#    1205         is_global_attn=is_global_attn,
#    1206         output_attentions=output_attentions,
#    1207     )
#    1208     attn_output = self_attn_outputs[0]
#    1209     outputs = self_attn_outputs[1:]
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/models/longformer/modeling_longformer.py:1135, in LongformerAttention.forward(self, hidden_states, attention_mask, layer_head_mask, is_index_masked, is_index_global_attn, is_global_attn, output_attentions)
#    1125 def forward(
#    1126     self,
#    1127     hidden_states,
#    (...)   1133     output_attentions=False,
#    1134 ):
# -> 1135     self_outputs = self.self(
#    1136         hidden_states,
#    1137         attention_mask=attention_mask,
#    1138         layer_head_mask=layer_head_mask,
#    1139         is_index_masked=is_index_masked,
#    1140         is_index_global_attn=is_index_global_attn,
#    1141         is_global_attn=is_global_attn,
#    1142         output_attentions=output_attentions,
#    1143     )
#    1144     attn_output = self.output(self_outputs[0], hidden_states)
#    1145     outputs = (attn_output,) + self_outputs[1:]
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/models/longformer/modeling_longformer.py:604, in LongformerSelfAttention.forward(self, hidden_states, attention_mask, layer_head_mask, is_index_masked, is_index_global_attn, is_global_attn, output_attentions)
#     601 # compute local attention output with global attention value and add
#     602 if is_global_attn:
#     603     # compute sum of global and local attn
# --> 604     attn_output = self._compute_attn_output_with_global_indices(
#     605         value_vectors=value_vectors,
#     606         attn_probs=attn_probs,
#     607         max_num_global_attn_indices=max_num_global_attn_indices,
#     608         is_index_global_attn_nonzero=is_index_global_attn_nonzero,
#     609         is_local_index_global_attn_nonzero=is_local_index_global_attn_nonzero,
#     610     )
#     611 else:
#     612     # compute local attn only
#     613     attn_output = self._sliding_chunks_matmul_attn_probs_value(
#     614         attn_probs, value_vectors, self.one_sided_attn_window_size
#     615     )
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/models/longformer/modeling_longformer.py:971, in LongformerSelfAttention._compute_attn_output_with_global_indices(self, value_vectors, attn_probs, max_num_global_attn_indices, is_index_global_attn_nonzero, is_local_index_global_attn_nonzero)
#     966 attn_probs_without_global = attn_probs.narrow(
#     967     -1, max_num_global_attn_indices, attn_probs.size(-1) - max_num_global_attn_indices
#     968 ).contiguous()
#     970 # compute attn output with global
# --> 971 attn_output_without_global = self._sliding_chunks_matmul_attn_probs_value(
#     972     attn_probs_without_global, value_vectors, self.one_sided_attn_window_size
#     973 )
#     974 return attn_output_only_global + attn_output_without_global
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/models/longformer/modeling_longformer.py:876, in LongformerSelfAttention._sliding_chunks_matmul_attn_probs_value(self, attn_probs, value, window_overlap)
#     868 chunked_value_stride = (
#     869     chunked_value_stride[0],
#     870     window_overlap * chunked_value_stride[1],
#     871     chunked_value_stride[1],
#     872     chunked_value_stride[2],
#     873 )
#     874 chunked_value = padded_value.as_strided(size=chunked_value_size, stride=chunked_value_stride)
# --> 876 chunked_attn_probs = self._pad_and_diagonalize(chunked_attn_probs)
#     878 context = torch.einsum("bcwd,bcdh->bcwh", (chunked_attn_probs, chunked_value))
#     879 return context.view(batch_size, num_heads, seq_len, head_dim).transpose(1, 2)
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/transformers/models/longformer/modeling_longformer.py:699, in LongformerSelfAttention._pad_and_diagonalize(chunked_hidden_states)
#     667 """
#     668 shift every row 1 step right, converting columns into diagonals.
#     669
#    (...)    696                -0.0405, 0.1599, 0.0000 0.0000, 0.0000, 0.0000, 2.0514, -1.1600, 0.5372, 0.2629 ]
#     697 """
#     698 total_num_heads, num_chunks, window_overlap, hidden_dim = chunked_hidden_states.size()
# --> 699 chunked_hidden_states = nn.functional.pad(
#     700     chunked_hidden_states, (0, window_overlap + 1)
#     701 )  # total_num_heads x num_chunks x window_overlap x (hidden_dim+window_overlap+1). Padding value is not important because it'll be overwritten
#     702 chunked_hidden_states = chunked_hidden_states.view(
#     703     total_num_heads, num_chunks, -1
#     704 )  # total_num_heads x num_chunks x window_overlap*window_overlap+window_overlap
#     705 chunked_hidden_states = chunked_hidden_states[
#     706     :, :, :-window_overlap
#     707 ]  # total_num_heads x num_chunks x window_overlap*window_overlap
#
# File /workspace/ss25-nn-project/.venv/lib/python3.13/site-packages/torch/nn/functional.py:5290, in pad(input, pad, mode, value)
#    5283         if mode == "replicate":
#    5284             # Use slow decomp whose backward will be in terms of index_put.
#    5285             # importlib is required because the import cannot be top level
#    5286             # (cycle) and cannot be nested (TS doesn't support)
#    5287             return importlib.import_module(
#    5288                 "torch._decomp.decompositions"
#    5289             )._replication_pad(input, pad)
# -> 5290 return torch._C._nn.pad(input, pad, mode, value)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.69 GiB. GPU 0 has a total capacity of 23.57 GiB of which 647.31 MiB is free. Process 128521 has 22.93 GiB memory in use. Of the allocated memory 21.03 GiB is allocated by PyTorch, and 1.66 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
epochs = 3

# %%
with epoch in range(epochs):
    for batch in train_dl:
        ...
